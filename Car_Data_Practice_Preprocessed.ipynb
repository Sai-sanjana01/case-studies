# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Venkat\Downloads\Project+2+-+Cars+Dataset.csv")

# %%
df
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df.head(5)
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %% [markdown]
# 1.head()
# 2. shape
# 3. index
# 4. columns
# 5. dtypes
# 6. unique()
# 7. nunique()
# 8. count
# 9. value_counts
# 10. info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         428 non-null    object
#  1   Model        428 non-null    object
#  2   Type         428 non-null    object
#  3   Origin       428 non-null    object
#  4   DriveTrain   428 non-null    object
#  5   MSRP         428 non-null    object
#  6   Invoice      428 non-null    object
#  7   EngineSize   428 non-null    float64
#  8   Cylinders    426 non-null    float64
#  9   Horsepower   428 non-null    float64
#  10  MPG_City     428 non-null    float64
#  11  MPG_Highway  428 non-null    float64
#  12  Weight       428 non-null    float64
#  13  Wheelbase    428 non-null    float64
#  14  Length       428 non-null    float64
# dtypes: float64(8), object(7)
# memory usage: 50.8+ KB

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP', 'Invoice',
#        'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
#        'Weight', 'Wheelbase', 'Length'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Make            object
# Model           object
# Type            object
# Origin          object
# DriveTrain      object
# MSRP            object
# Invoice         object
# EngineSize     float64
# Cylinders      float64
# Horsepower     float64
# MPG_City       float64
# MPG_Highway    float64
# Weight         float64
# Wheelbase      float64
# Length         float64
# dtype: object

# %%
df.shape
# Out:
# (432, 15)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=432, step=1)

# %%
df.nunique()
# Out:
# Make            38
# Model          425
# Type             6
# Origin           3
# DriveTrain       3
# MSRP           410
# Invoice        425
# EngineSize      43
# Cylinders        7
# Horsepower     110
# MPG_City        28
# MPG_Highway     33
# Weight         348
# Wheelbase       40
# Length          67
# dtype: int64

# %%
df["Model"].unique()
# Out:
# array(['MDX', 'RSX Type S 2dr', 'TSX 4dr', 'TL 4dr', '3.5 RL 4dr',
#        '3.5 RL w/Navigation 4dr', 'NSX coupe 2dr manual S', 'A4 1.8T 4dr',
#        'A41.8T convertible 2dr', 'A4 3.0 4dr',
#        'A4 3.0 Quattro 4dr manual', 'A4 3.0 Quattro 4dr auto',
#        'A6 3.0 4dr', 'A6 3.0 Quattro 4dr', 'A4 3.0 convertible 2dr',
#        'A4 3.0 Quattro convertible 2dr', 'A6 2.7 Turbo Quattro 4dr',
#        'A6 4.2 Quattro 4dr', 'A8 L Quattro 4dr', 'S4 Quattro 4dr',
#        'RS 6 4dr', 'TT 1.8 convertible 2dr (coupe)',
#        'TT 1.8 Quattro 2dr (convertible)',
#        'TT 3.2 coupe 2dr (convertible)', 'A6 3.0 Avant Quattro',
#        'S4 Avant Quattro', 'X3 3.0i', 'X5 4.4i', '325i 4dr', '325Ci 2dr',
#        nan, '325Ci convertible 2dr', '325xi 4dr', '330i 4dr', '330Ci 2dr',
#        '330xi 4dr', '525i 4dr', '330Ci convertible 2dr', '530i 4dr',
#        '545iA 4dr', '745i 4dr', '745Li 4dr', 'M3 coupe 2dr',
#        'M3 convertible 2dr', 'Z4 convertible 2.5i 2dr',
# ...

# %%
df["Model"].value_counts()
# Out:
# Model
# G35 4dr                                    2
# C320 4dr                                   2
# C240 4dr                                   2
# MDX                                        1
# Marauder 4dr                               1
#                                           ..
# Ranger 2.3 XL Regular Cab                  1
# F-150 Supercab Lariat                      1
# F-150 Regular Cab XL                       1
# Thunderbird Deluxe convert w/hardtop 2d    1
# XC70                                       1
# Name: count, Length: 425, dtype: int64

# %%
df.count()
# Out:
# Make           428
# Model          428
# Type           428
# Origin         428
# DriveTrain     428
# MSRP           428
# Invoice        428
# EngineSize     428
# Cylinders      426
# Horsepower     428
# MPG_City       428
# MPG_Highway    428
# Weight         428
# Wheelbase      428
# Length         428
# dtype: int64

# %% [markdown]
# ## 1) Instruction(For data cleaning)
# ##### + Find all null values in the dataset. if there is any null value in any columns then fill it with the mean of the column .

# %%
df.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Make           428
# Model          428
# Type           428
# Origin         428
# DriveTrain     428
# MSRP           428
# Invoice        428
# EngineSize     428
# Cylinders      426
# Horsepower     428
# MPG_City       428
# MPG_Highway    428
# Weight         428
# Wheelbase      428
# Length         428
# dtype: int64

# %%
df.notna().sum()
# Out:
# Make           428
# Model          428
# Type           428
# Origin         428
# DriveTrain     428
# MSRP           428
# Invoice        428
# EngineSize     428
# Cylinders      426
# Horsepower     428
# MPG_City       428
# MPG_Highway    428
# Weight         428
# Wheelbase      428
# Length         428
# dtype: int64

# %%
df.describe(include = "all")
# Out:
#           Make    Model   Type Origin DriveTrain      MSRP   Invoice  \
# count      428      428    428    428        428       428       428
# unique      38      425      6      3          3       410       425
# top     Toyota  G35 4dr  Sedan   Asia      Front  $33,995   $19,638
# freq        28        2    262    158        226         2         2
# mean       NaN      NaN    NaN    NaN        NaN       NaN       NaN
# std        NaN      NaN    NaN    NaN        NaN       NaN       NaN
# min        NaN      NaN    NaN    NaN        NaN       NaN       NaN
# 25%        NaN      NaN    NaN    NaN        NaN       NaN       NaN
# 50%        NaN      NaN    NaN    NaN        NaN       NaN       NaN
# 75%        NaN      NaN    NaN    NaN        NaN       NaN       NaN
# max        NaN      NaN    NaN    NaN        NaN       NaN       NaN
#
#         EngineSize   Cylinders  Horsepower    MPG_City  MPG_Highway  \
# count   428.000000  426.000000  428.000000  428.000000   428.000000
# ...

# %%
df["Cylinders"].fillna(df["Cylinders"].mean(), inplace = True)
# Out:
# C:\Users\Venkat\AppData\Local\Temp\ipykernel_16784\1818092654.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Cylinders"].fillna(df["Cylinders"].mean(), inplace = True)

# %%
df.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
df["Make"] = df["Make"].fillna("Unknown")

# %%
df["Model"] = df["Model"].fillna("Unknown")

# %%
df[["Type","Origin","DriveTrain","MSRP","Invoice"]]= df[["Type","Origin","DriveTrain","MSRP","Invoice"]].fillna("Unkown")

# %%
columns_to_fill = ["EngineSize","Horsepower","MPG_City","MPG_Highway","Weight","Wheelbase","Length"]

# %%
df[columns_to_fill] = df[columns_to_fill].fillna(df[columns_to_fill].mean())

# %%
df.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0

# %% [markdown]
# ## 2) Question (based on value counts)
# ##### + check what are the different types of make are there in our dataset. And what is the count (occurrence) of each make in the data?

# %%
df["Make"].value_counts()
# Out:
# Make
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Subaru           11
# Pontiac          11
# Mazda            11
# Lexus            11
# Kia              11
# Buick             9
# Mercury           9
# Lincoln           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: count, dtype: int64

# %% [markdown]
# ## 3) Instruction(filtering)
# + show all the records where origin is asia or europe

# %%
df[(df["Origin"]== "Asia")| (df["Origin"]== "Europe")]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df[df["Origin"].isin(["Asia", "Europe"])]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# ## 4) Instruction (Remove unwanted records)
# + Remove all the records (rows) where weight is above 4000

# %%
df[~(df["Weight"]> 4000)]   ## to remove the records
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan    Asia      Front  $46,100
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# ## 5) Instruction (Applying function on a column)
# + Increase all the values of "MPG_City column by 3"

# %%
df.head(2)
# Out:
#       Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Unknown             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Unknown  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0

# %%
df["MPG_City"]= df["MPG_City"].apply(lambda x:x+3)

# %%
df
# Out:
#         Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Unknown                      MDX    SUV    Asia        All  $36,945
# 1    Unknown           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Unknown                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Unknown                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Unknown               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..       ...                      ...    ...     ...        ...       ...
# 427  Unknown  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Unknown  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Unknown               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Unknown                      V40  Wagon  Europe      Front  $26,135
# 431  Unknown                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df[df["Type"].isin(["Seden","SUV"])]
# Out:
#         Make                            Model Type  Origin DriveTrain  \
# 0    Unknown                              MDX  SUV    Asia        All
# 26   Unknown                          X3 3.0i  SUV  Europe        All
# 27   Unknown                          X5 4.4i  SUV  Europe        All
# 48   Unknown                          Rainier  SUV     USA        All
# 49   Unknown                    Rendezvous CX  SUV     USA      Front
# 57   Unknown                         Escalade  SUV     USA      Front
# 58   Unknown                           SRX V8  SUV     USA      Front
# 65   Unknown                 Suburban 1500 LT  SUV     USA      Front
# 66   Unknown                         Tahoe LT  SUV     USA        All
# 67   Unknown                   TrailBlazer LT  SUV     USA      Front
# 68   Unknown                          Tracker  SUV     USA      Front
# 107  Unknown                      Durango SLT  SUV     USA        All
# ...
